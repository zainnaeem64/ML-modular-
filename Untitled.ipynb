# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
# app.py   demo.py     notebook/         setup.py        us_visa/
# config/  Dockerfile  README.md         template.py     us_visa.egg-info/
# data/    logs/       requirements.txt  Untitled.ipynb

# %%
df=pd.read_csv('data/EasyVisa.csv')

# %%
df.case_status.value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
df.no_of_employees
# Out:
# 0        14513
# 1         2412
# 2        44444
# 3           98
# 4         1082
#          ...
# 25475     2601
# 25476     3274
# 25477     1121
# 25478     1918
# 25479     3195
# Name: no_of_employees, Length: 25480, dtype: int64

# %%
# Plotting a basic histogram
plt.hist(df.prevailing_wage, bins=30, color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')

# Display the plot
plt.show()

# %%
data1=df[df.case_status=='Denied']['prevailing_wage']
data2=df[df.case_status=='Certified']['prevailing_wage']

plt.hist([data2,data1], bins=30, stacked=True, color=['cyan', 'Purple'], edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')

# Adding legend
plt.legend(['Dataset 1', 'Dataset 2'])

# Display the plot
plt.show()

# %%
plt.hist(data1, bins=30, stacked=True, color=[ 'Purple'], edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')

# Adding legend
plt.legend(['',])

# Display the plot
plt.show()

# %%
plt.hist(data2, bins=30, stacked=True, color=[ 'Purple'], edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Stacked Histogram')

# Adding legend
plt.legend(['Dataset 1', 'Dataset 2'])

# Display the plot
plt.show()

# %%
df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
target=df.case_status

# %%
numercial=[feature for feature in df.columns if df[feature].dtype != 'O']
catagorical=[feature for feature in df.columns if df[feature].dtype == 'O']

# %%
numercial_feat=pd.concat([df[numercial],target],axis=1)

# %%
categorical_feat=df[catagorical]

# %%
catagorical
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
pd.crosstab(df['has_job_experience'],target).plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='has_job_experience'>

# %%
sns.countplot(x='has_job_experience',hue='case_status',data=df)
# Out:
# <Axes: xlabel='has_job_experience', ylabel='count'>
